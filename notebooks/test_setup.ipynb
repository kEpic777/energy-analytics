# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Uporabnik\miniconda3\envs\energy\python.exe

# %%
import sys
import pandas as pd
import numpy as np
import duckdb

print("Python:", sys.executable)
print("pandas:", pd.__version__)
print("numpy:", np.__version__)
print("duckdb:", duckdb.__version__)
# Out:
# Python: c:\Users\Uporabnik\miniconda3\envs\energy\python.exe
# pandas: 3.0.1
# numpy: 2.4.2
# duckdb: 1.4.4

# %%
import matplotlib.pyplot as plt

# %%
print ("matplotlib:", matplotlib.__version__)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print ("matplotlib:", plt.__version__)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute '__version__'

# %%
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import duckdb

print("Python:", sys.executable)
print("pandas:", pd.__version__)
print("numpy:", np.__version__)
print("duckdb:", duckdb.__version__)

plt.plot([1,2,3],[1,4,9])
plt.title("Matplotlib test")
plt.show()
# Out:
# Python: c:\Users\Uporabnik\miniconda3\envs\energy\python.exe
# pandas: 3.0.1
# numpy: 2.4.2
# duckdb: 1.4.4
